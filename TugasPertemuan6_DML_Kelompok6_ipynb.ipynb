# %% [markdown]
# <a href="https://colab.research.google.com/github/lauracantik/dataminingg/blob/main/TugasPertemuan6_DML_Kelompok6_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import runtime

# fungsi untuk menampilkan menu
def show_menu():
  print ("\n")
  print ("----------- MENU ----------")
  print ("[1] Show Data")
  print ("[2] Insert Data")
  print ("[3] Edit Data")
  print ("[4] Delete Data")
  print ("[5] Exit")
  menu = int(input("PILIH MENU> "))

  print ("\n")
  if menu == 1:
    show_data()
  elif menu == 2:
    insert_data()
  elif menu == 3:
    edit_data()
  elif menu == 4:
    delete_data()
  elif menu == 5:
    runtime.unassign()
    exit()
  else:
    print ("Salah pilih!")

# if __name__ == "__main__":
#   while(True):
#     show_menu()

# Variabel global untuk menyimpan data Buku
buku = []
# fungsi untuk menampilkan semua data
def show_data():
  if len(buku) <= 0:
    print ("BELUM ADA DATA")
  else:
    for indeks in range(len(buku)):
      print ("[%d] %s" % (indeks, buku[indeks]))
      # fungsi untuk menambah data
def insert_data():
  buku_baru = input("Judul Buku: ")
  buku.append(buku_baru)


# fungsi untuk edit data
def edit_data():
  show_data()
  indeks = int(input("Inputkan ID buku: "))
  if(indeks > len(buku)):
    print ("ID salah")
  else:
    judul_baru = input("Judul baru: ")
    buku[indeks] = judul_baru

# fungsi untuk menhapus data
def delete_data():
  show_data()
  indeks = int(input("Inputkan ID buku: "))
  if(indeks > len(buku)):
    print("ID salah")
  else:
    buku.remove(buku[indeks])

if __name__ == "__main__":
  while(True):
    show_menu()
# Out:
# ----------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU> 1
#
#
# BELUM ADA DATA
#
#
# ----------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU> 2
#
#
# Judul Buku: AntiVirus 2020 - Charles Agandhi
#
#
# ----------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU> 1
#
#
# [0] AntiVirus 2020 - Charles Agandhi
#
#
# ----------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU> 2
#
#
# Judul Buku: Problem Solving 2018 - Amanda Natchar
#
#
# ----------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# [4] Delete Data
# [5] Exit
# PILIH MENU> 1
#
#
# [0] AntiVirus 2020 - Charles Agandhi
# [1] Problem Solving 2018 - Amanda Natchar
#
#
# ----------- MENU ----------
# [1] Show Data
# [2] Insert Data
# [3] Edit Data
# ...
